# %% [markdown]
# <a href="https://colab.research.google.com/github/daviddsdp/DATABASE/blob/main/News%2C_all_is_new!.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title

from urllib import request
from IPython.display import display,HTML, IFrame

def template():
  url = input("")
  response = request.urlopen(url)
  raw = response.read().decode('utf8')
  Raw = raw.replace(input(""),input(""))
  return display(HTML(Raw))

# %% [markdown]
# ![Label.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Icon

# %% [markdown]
# ![Workflow.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Workflow, vizualitation

# %%
#@title: Display the content of the web, manipulate it and display again. 
#Repeat this workflow until your reach your goal.    
template()
# Out:
# https://es.wikipedia.org/wiki/Caiman
# Caiman
# Lacoste
# <!DOCTYPE html>
# <html class="client-nojs" lang="es" dir="ltr">
# <head>
# <meta charset="UTF-8"/>
# <title>Lacoste - Wikipedia, la enciclopedia libre</title>
# ...
